# %% [markdown]
# ## 1주차 미션 소개 - 머신러닝 과정 이해하기
#
# * 미션 목적
#     * 머신러닝 모델을 실행하는 기본 과정을 이해하기 (학습 => 예측 => 평가)
#     * Scikit-learn API 기본 사용법 익히기
#     * 학습을 하기 위해 학습, 예측 데이터를 나누는 방법
#     * 학습(train, 기출문제, 정답이 있음), 예측(test, 실전 문제, 정답이 없음)
#     * 학습(fit)과 예측(predict)을 하고 평가를 하는 방법
#     * 머신러닝 알고리즘 중에 좋은 성능을 내는 boosting 알고리즘의 기본이 되는 DecisionTree 를 사용
#     * DecisionTree 의 기본적인 원리 이해하기
#
# * 미션 데이터셋 소개
#
#     * 해당 Kaggle 데이터셋( https://www.kaggle.com/blastchar/telco-customer-churn )은 통신사 고객 이탈(Churn)에 대한 정보를 담고 있습니다. IBM에서 제공한 이 데이터셋은 고객 유지에 필요한 행동을 예측하는 데 사용될 수 있으며, 고객 데이터를 분석하여 고객 유지 프로그램을 개발하는 데 도움이 됩니다.
#     * 해당 데이터셋은 다음의 정보로 구성되어 있습니다.
#         * 고객 인구 통계 정보(Demographic info): 고객의 성별, 연령대, 배우자 및 부양 가족의 유무(Gender, SeniorCitizen, Partner, Dependents) 등에 관한 정보가 포함되어 있습니다.
#         * 고객 이탈(Churn) 정보: 서비스를 중단 여부에 대한 정보가 포함되어 있습니다.
#         * 서비스 가입 정보(Services subscribed): 고객들이 가입한 서비스들, 예를 들어 전화, 다중 라인, 인터넷, 온라인 보안, 온라인 백업, 장치 보호, 기술 지원, 스트리밍 TV 및 영화( honeService, MultipleLine, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies) 등에 대한 정보가 있습니다.
#         * 고객 계정 정보(Customer account info): 고객이 얼마나 오래 서비스를 이용했는지, 계약 유형, 결제 방법, 무페이퍼 청구 여부, 월별 요금, 총 요금 (CustomerID, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Tenure)등의 정보가 담겨 있습니다.
#
#
# * 해당 미션으로 시도해 볼 수 있는 현실 세계 문제
#     * 이탈 예측 모델링: 가장 일반적인 사용 사례로, 고객의 이탈 가능성을 예측하는 모델을 구축합니다. 이러한 모델은 고객의 과거 데이터와 행동 패턴을 분석하여 누가 이탈할 가능성이 높은지 예측합니다.
#
#     * 고객 세분화: 고객을 다양한 그룹으로 세분화하여, 특정 그룹이 왜 더 높은 이탈률을 보이는지 이해할 수 있습니다. 이를 통해 타겟 마케팅 전략을 개발하거나 특정 고객 그룹에 더 맞춤화된 서비스를 제공할 수 있습니다.
#
#     * 원인 분석: 머신러닝 모델을 사용하여 고객 이탈의 주요 원인을 파악할 수 있습니다. 예를 들어, 서비스 품질, 가격, 고객 서비스 경험 등 다양한 요인이 고객 이탈에 어떤 영향을 미치는지 분석할 수 있습니다. 피처의 중요도를 파악하고 어떤 요인이 이탈의 중요한 피처인지를 확인해 봅니다.
#
#     * 추천 시스템 개선: 이탈 위험이 있는 고객에게 맞춤형 서비스나 제품을 추천하여 고객 만족도를 높이고 이탈률을 줄일 수 있습니다.
#
#     * 고객 유지 전략 개발: 이탈 예측 모델을 활용해 고위험 고객을 식별하고, 이들을 대상으로 특별 프로모션, 개선된 고객 서비스, 맞춤형 커뮤니케이션 전략 등을 제공하여 이탈률을 줄일 수 있습니다.
#
#     * 정책 및 서비스 개선: 모델에서 도출된 인사이트를 바탕으로 비즈니스 정책, 제품, 서비스를 개선하여 전반적인 고객 경험을 향상시킬 수 있습니다.

# %%
# 미션 진행을 위해 필요한 라이브러리를 로드합니다.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 미션 수행을 위해 데이터를 로드합니다.
df = pd.read_csv("https://bit.ly/telco-csv", index_col="customerID")
df.shape
# Out:
# (7043, 20)

# %%
# 데이터 프레임에서 가장 앞에 있는 N개의 행을 출력합니다.
df.head(2)
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
#
#                   Contract PaperlessBilling     PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG  Month-to-month              Yes  Electronic check           29.85
# 5575-GNVDE        One year               No      Mailed check           56.95
#
#            TotalCharges Churn
# customerID
# 7590-VHVEG        29.85    No
# 5575-GNVDE       1889.5    No

# %%
# 데이터 집합과 각 열들의 자료형을 확인합니다.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   object
#  19  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
# df.isnull().sum()는 컬럼별로 결측치의 합계를 구합니다.
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# df.isnull().sum().sum() 전체 결측치의 합계를 구합니다.
df.isnull().sum().sum()
# Out:
# 0

# %%
# 숫자형태로 된 문자열을 숫자형으로 바꿔줍니다.
# 공백문자 등의 결측치가 들어있다면 .str.strip()을 통해 공백문자를 제거합니다.
# .replace("", np.nan) 는 공백문자를 결측치로 변경해 줍니다.
# .astype(float) 으로 수치형태로 변환해 줍니다.
df["TotalCharges"] = df["TotalCharges"].str.strip().replace("", np.nan).astype(float)

# %%
df["TotalCharges"].head(1)
# Out:
# customerID
# 7590-VHVEG    29.85
# Name: TotalCharges, dtype: float64

# %%
# 결측치를 채워주는 방법도 있지만 일단 제거하도록 합니다.
# 결측치를 채우는 방법도 여러 가지가 있는데 여기에서는 결측치 11개는 그렇게 결측치가 많은 편이 아니고
# 임의의 수로 채워준다면 실제값과 유사한 값을 알아서 채워주지 않으면 오히려 예측의 성능이 떨어질 수 있습니다.
# 예를 들어 아무숫자로 채우기위해 0으로 채운다면 실제 낸 금액은 훨씬 많을텐데 모델을 더 혼란스럽게 만들 수 있습니다.
# 중간값, 평균값 등의 대푯값으로 채운다면 해당 데이터에서 제공하는
# 인구통계학적인 정보, 구독정보 등을 참고해서 해당 세그먼트에서의 대푯값으로 채우는 것을 추천합니다.
df = df.dropna()
df.isnull().sum().sum()
# Out:
# 0

# %%
# 바이너리 변수 인코딩을 위해 범주 값이 2개로 되어 있어 이진값으로 인코딩이 가능한 변수를 찾습니다.
nuniq = df.nunique()
bi_cols = nuniq[nuniq == 2].index
bi_cols
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'PaperlessBilling', 'Churn'],
#       dtype='object')

# %%
df[bi_cols]
# Out:
#             gender  SeniorCitizen Partner Dependents PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No           No
# 5575-GNVDE    Male              0      No         No          Yes
# 3668-QPYBK    Male              0      No         No          Yes
# 7795-CFOCW    Male              0      No         No           No
# 9237-HQITU  Female              0      No         No          Yes
# ...            ...            ...     ...        ...          ...
# 6840-RESVB    Male              0     Yes        Yes          Yes
# 2234-XADUH  Female              0     Yes        Yes          Yes
# 4801-JZAZL  Female              0     Yes        Yes           No
# 8361-LTMKD    Male              1     Yes         No          Yes
# 3186-AJIEK    Male              0      No         No          Yes
#
#            PaperlessBilling Churn
# customerID
# 7590-VHVEG              Yes    No
# 5575-GNVDE               No    No
# 3668-QPYBK              Yes   Yes
# 7795-CFOCW               No    No
# 9237-HQITU              Yes   Yes
# ...                     ...   ...
# 6840-RESVB              Yes    No
# 2234-XADUH              Yes    No
# 4801-JZAZL              Yes    No
# 8361-LTMKD              Yes   Yes
# 3186-AJIEK              Yes    No
#
# [7032 rows x 7 columns]

# %%
# 바이너리 변수에 대한 인코딩
df["gender_encode"] = (df["gender"] == "Male").astype(int)
df["Partner_encode"] = (df["Partner"] == "Yes").astype(int)
df["Dependents_encode"] = (df["Dependents"] == "Yes").astype(int)
df["PhoneService_encode"] = (df["PhoneService"] == "Yes").astype(int)
df["PaperlessBilling_encode"] = (df["PaperlessBilling"] == "Yes").astype(int)
df
# Out:
# <ipython-input-12-80cb35d4a17d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gender_encode"] = (df["gender"] == "Male").astype(int)
# <ipython-input-12-80cb35d4a17d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Partner_encode"] = (df["Partner"] == "Yes").astype(int)
# <ipython-input-12-80cb35d4a17d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Dependents_encode"] = (df["Dependents"] == "Yes").astype(int)
# <ipython-input-12-80cb35d4a17d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PhoneService_encode"] = (df["PhoneService"] == "Yes").astype(int)
# <ipython-input-12-80cb35d4a17d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PaperlessBilling_encode"] = (df["PaperlessBilling"] == "Yes").astype(int)
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# ...            ...            ...     ...        ...     ...          ...
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# customerID                                                                ...
# 7590-VHVEG  No phone service             DSL             No          Yes  ...
# 5575-GNVDE                No             DSL            Yes           No  ...
# 3668-QPYBK                No             DSL            Yes          Yes  ...
# 7795-CFOCW  No phone service             DSL            Yes           No  ...
# 9237-HQITU                No     Fiber optic             No           No  ...
# ...                      ...             ...            ...          ...  ...
# 6840-RESVB               Yes             DSL            Yes           No  ...
# 2234-XADUH               Yes     Fiber optic             No          Yes  ...
# 4801-JZAZL  No phone service             DSL            Yes           No  ...
# 8361-LTMKD               Yes     Fiber optic             No           No  ...
# 3186-AJIEK                No     Fiber optic            Yes           No  ...
#
#            PaperlessBilling              PaymentMethod MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check          29.85
# 5575-GNVDE               No               Mailed check          56.95
# 3668-QPYBK              Yes               Mailed check          53.85
# 7795-CFOCW               No  Bank transfer (automatic)          42.30
# 9237-HQITU              Yes           Electronic check          70.70
# ...                     ...                        ...            ...
# 6840-RESVB              Yes               Mailed check          84.80
# 2234-XADUH              Yes    Credit card (automatic)         103.20
# 4801-JZAZL              Yes           Electronic check          29.60
# 8361-LTMKD              Yes               Mailed check          74.40
# 3186-AJIEK              Yes  Bank transfer (automatic)         105.65
#
#            TotalCharges Churn gender_encode Partner_encode  Dependents_encode  \
# customerID
# 7590-VHVEG        29.85    No             0              1                  0
# 5575-GNVDE      1889.50    No             1              0                  0
# 3668-QPYBK       108.15   Yes             1              0                  0
# 7795-CFOCW      1840.75    No             1              0                  0
# 9237-HQITU       151.65   Yes             0              0                  0
# ...                 ...   ...           ...            ...                ...
# 6840-RESVB      1990.50    No             1              1                  1
# 2234-XADUH      7362.90    No             0              1                  1
# 4801-JZAZL       346.45    No             0              1                  1
# 8361-LTMKD       306.60   Yes             1              1                  0
# 3186-AJIEK      6844.50    No             1              0                  0
#
#             PhoneService_encode PaperlessBilling_encode
# customerID
# 7590-VHVEG                    0                       1
# 5575-GNVDE                    1                       0
# 3668-QPYBK                    1                       1
# 7795-CFOCW                    0                       0
# 9237-HQITU                    1                       1
# ...                         ...                     ...
# 6840-RESVB                    1                       1
# 2234-XADUH                    1                       1
# 4801-JZAZL                    0                       1
# 8361-LTMKD                    1                       1
# 3186-AJIEK                    1                       1
#
# [7032 rows x 25 columns]

# %%
# 정답의 빈도수 확인
df["Churn"].value_counts()
# Out:
# No     5163
# Yes    1869
# Name: Churn, dtype: int64

# %%
# value_counts(1) => normalize=True 와 같습니다.
df["Churn"].value_counts(1)
# Out:
# No     0.734215
# Yes    0.265785
# Name: Churn, dtype: float64

# %%
sns.countplot(data=df, x="Churn")
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ## 미션 1) - 학습, 예측 데이터셋 나누기
#
# <img src="https://i.imgur.com/yvBtRtJ.png" width="600">
#
# * X_train : feature_names 에 해당되는 컬럼만 train에서 가져옵니다.
#     * 학습(훈련)에 사용할 데이터셋 예) 시험의 기출문제
#
# * X_test : feature_names 에 해당되는 컬럼만 test에서 가져옵니다.
#     * 예측에 사용할 데이터셋 예) 실전 시험문제
#
# * y_train : label_name 에 해당 되는 컬럼만 train에서 가져옵니다.
#     * 학습(훈련)에 사용할 정답 값 예) 기출문제의 정답
#
# * y_test : label_name 에 해당 되는 컬럼만 test에서 가져옵니다.
#     * 예측에 사용할 정답 값 예) 실전 문제의 정답
#
#
# * 아래의 형태로 데이터셋을 나누되, train 데이터셋의 shape 는 (5625, 9), test 데이터셋의 shape 는 (1407, 9) 이 되도록 합니다. 행의 customerID 는 섞여도 상관 없으며 아래와 순서가 달라도 되며, train, test의 shape 값의 행의 수가 8:2 로 나뉘면 됩니다.
#
#
# | customerID   |   SeniorCitizen |   tenure |   MonthlyCharges |   TotalCharges |   gender_encode |   Partner_encode |   Dependents_encode |   PhoneService_encode |   PaperlessBilling_encode |
# |:-------------|----------------:|---------:|-----------------:|---------------:|----------------:|-----------------:|--------------------:|----------------------:|--------------------------:|
# | 7590-VHVEG   |               0 |        1 |            29.85 |          29.85 |               0 |                1 |                   0 |                     0 |                         1 |
# | 5575-GNVDE   |               0 |       34 |            56.95 |        1889.5  |               1 |                0 |                   0 |                     1 |                         0 |
#
#
# | customerID   |   SeniorCitizen |   tenure |   MonthlyCharges |   TotalCharges |   gender_encode |   Partner_encode |   Dependents_encode |   PhoneService_encode |   PaperlessBilling_encode |
# |:-------------|----------------:|---------:|-----------------:|---------------:|----------------:|-----------------:|--------------------:|----------------------:|--------------------------:|
# | 2320-JRSDE   |               0 |        1 |             19.9 |          19.9  |               0 |                1 |                   1 |                     1 |                         1 |
# | 2087-QAREY   |               0 |       22 |             54.7 |        1178.75 |               0 |                1 |                   0 |                     1 |                         1 |
#
#
#
# ### 학습, 예측에 사용할 컬럼

# %%
# 학습, 예측에 사용할 컬럼에 이름 지정합니다.
# 범주형 데이터(object, category)는 전처리가 따로 필요합니다.
# 간단하게 모델을 만들어보기 위해 수치 데이터만 사용합니다.
feature_names = df.select_dtypes(include="number").columns
feature_names
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges',
#        'gender_encode', 'Partner_encode', 'Dependents_encode',
#        'PhoneService_encode', 'PaperlessBilling_encode'],
#       dtype='object')

# %% [markdown]
# ### 정답값이자 예측해야 될 값

# %%
# label_name 이라는 변수에 예측할 컬럼(Churn)의 이름을 담습니다.
label_name = "Churn"
label_name
# Out:
# 'Churn'

# %% [markdown]
# ### 문제(feature)와 답안(label)을 나누기
#
# * X, y를 만들어 줍니다.
# * X는 feature, 독립변수, 예) 시험의 문제
# * y는 label, 종속변수, 예) 시험의 정답
#
# * 결과는 다음과 같은 형태로 나오도록 합니다.
#
# * X 값 출력 예시 입니다.
#
# | customerID   |   SeniorCitizen |   tenure |   MonthlyCharges |   TotalCharges |   gender_encode |   Partner_encode |   Dependents_encode |   PhoneService_encode |   PaperlessBilling_encode |
# |:-------------|----------------:|---------:|-----------------:|---------------:|----------------:|-----------------:|--------------------:|----------------------:|--------------------------:|
# | 7590-VHVEG   |               0 |        1 |            29.85 |          29.85 |               0 |                1 |                   0 |                     0 |                         1 |
# | 5575-GNVDE   |               0 |       34 |            56.95 |        1889.5  |               1 |                0 |                   0 |                     1 |                         0 |
#
#
# * y 값 출력 예시 입니다.
#
# | customerID   | Churn   |
# |:-------------|:--------|
# | 7590-VHVEG   | No      |
# | 5575-GNVDE   | No      |
#
# * 데이터의 행과 열의 수 입니다.
#     * X 의 shape 출력 (7032, 9)
#     * y 의 shape 출력 (7032,)

# %%
# X, y를 만들어 줍니다.
# 물음표를 채워 독립변수(X)와 종속변수(y)를 나눠주세요.
# scikit-learn에서 데이터는 대문자 X(2차원,행렬)로 표시하고 정답은 소문자 y(1차원,벡터)로 표기합니다.
X = df[feature_names]
y = df[label_name]
display(X.head(2))
display(y.head(2))
X.shape, y.shape
# Out:
#             SeniorCitizen  tenure  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG              0       1           29.85         29.85
# 5575-GNVDE              0      34           56.95       1889.50
#
#             gender_encode  Partner_encode  Dependents_encode  \
# customerID
# 7590-VHVEG              0               1                  0
# 5575-GNVDE              1               0                  0
#
#             PhoneService_encode  PaperlessBilling_encode
# customerID
# 7590-VHVEG                    0                        1
# 5575-GNVDE                    1                        0
# customerID
# 7590-VHVEG    No
# 5575-GNVDE    No
# Name: Churn, dtype: object
# ((7032, 9), (7032,))

# %% [markdown]
# ### 학습, 예측 데이터셋 만들기
# * X_train : 학습 세트 만들기, 행렬, 판다스의 데이터프레임, 2차원 리스트(배열) 구조,  예) 시험의 기출문제
# * y_train : 정답 값을 만들기, 벡터, 판다스의 시리즈, 1차원 리스트(배열) 구조, 예) 기출문제의 정답
# * X_test : 예측에 사용할 데이터세트를 만듭니다. 예) 실전 시험 문제
# * y_test : 예측의 정답값 예) 실전 시험 문제의 정답
#
#
# * 10회까지의 모의고사 문제집이 있다고 가정할 때
# * 1~8회는 공부한다 풀어보고 : model.fit(X_train, y_train)
# * 9, 10회는 실전 문제처럼 풀어보고 : model.predict(X_test) => 결과를 y_predict 로 만들고
# * 채점하는 과정으로 학습과 예측을 할 예정입니다. : y_test, y_predict 실제값과 예측값을 비교해서 채점하게 됩니다.

# %%
# 데이터의 행과 열의 개수를 확인합니다.
df.shape
# Out:
# (7032, 25)

# %% [markdown]
# * 학습, 예측 데이터셋을 나눌 때는  5:5, 8:2, 7:3 등으로 나눌수도 있지만 학습데이터를 더 많이 나누는게 좋습니다.
# * 공부를 더 많이 하고 시험을 봐야지 시험을 더 잘 볼 수있기 때문입니다.
# * 8:2 를 기준으로 나눕니다. 아래의 내용은 tain.head(2), test.head(2)로 위에 있는 데이터를 미리보기 한 모습으로 예시 입니다.
#
#
# * X_train 출력 예시 입니다.
#
# | customerID   |   SeniorCitizen |   tenure |   MonthlyCharges |   TotalCharges |   gender_encode |   Partner_encode |   Dependents_encode |   PhoneService_encode |   PaperlessBilling_encode |
# |:-------------|----------------:|---------:|-----------------:|---------------:|----------------:|-----------------:|--------------------:|----------------------:|--------------------------:|
# | 7590-VHVEG   |               0 |        1 |            29.85 |          29.85 |               0 |                1 |                   0 |                     0 |                         1 |
# | 5575-GNVDE   |               0 |       34 |            56.95 |        1889.5  |               1 |                0 |                   0 |                     1 |                         0 |
#
# * X_test 출력 예시 입니다.
#
# | customerID   |   SeniorCitizen |   tenure |   MonthlyCharges |   TotalCharges |   gender_encode |   Partner_encode |   Dependents_encode |   PhoneService_encode |   PaperlessBilling_encode |
# |:-------------|----------------:|---------:|-----------------:|---------------:|----------------:|-----------------:|--------------------:|----------------------:|--------------------------:|
# | 2320-JRSDE   |               0 |        1 |             19.9 |          19.9  |               0 |                1 |                   1 |                     1 |                         1 |
# | 2087-QAREY   |               0 |       22 |             54.7 |        1178.75 |               0 |                1 |                   0 |                     1 |                         1 |
#
# * X_train, X_test 의 shape 출력 예시 입니다.
# (5625, 9), (1407, 9)

# %%
# train 과 test 로 나누기 위해 데이터를 기준을 정합니다.
split_count = int(df.shape[0] * 0.7)
split_count
# Out:
# 4922

# %% [markdown]
# * 다음 빈칸을 채워 학습, 예측 데이터셋을 만들어 주세요.
# * 빈칸을 채우는 방법 외 다른 방법으로 나눠도 됩니다.

# %%
# 데이터의 80%을 나눌 기준 인덱스(split_count)로 문제 데이터(X)를 train, test로 나눕니다.
# 데이터의 80%을 나눌 기준 인덱스(split_count)로 정답 데이터(y)를 train, test로 나눕니다.
X_train = X[:split_count]
y_train = y[:split_count]

X_test = X[split_count:]
y_test = y[split_count:]

print("* 데이터가 잘 나뉘었는지 shape 값을 통해 확인해 보세요.")

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# * 데이터가 잘 나뉘었는지 shape 값을 통해 확인해 보세요.
# ((4922, 9), (2110, 9), (4922,), (2110,))

# %% [markdown]
# 클래스가 여러 개 일 경우에 클래스의 수가 train, test에 균일하게 나뉘지 않을 수도 있습니다.
# train_test_split() 등의 기능을 사용하면 label값을 균형있게 나눠줄 수도 있습니다.
# 예를 들어 이탈여부를 예측하는데 이탈안한다 한다가 7:3 정도로 train에 있다면  test 에도 7:3 으로 들어있어야 제대로 학습하고 예측할 수 있습니다.
# 임의로 순서대로 나눴다면 train 에는 8:2 로 들어있는데 test 에는 6:4 로 들어있다면 예측의 성능이 떨어질 수도 있습니다.
# 불균형한 클래스를 다룰 때는 정답의 클래스를 같은 비율로 만들어 줄 때 언더샘플링, 오버샘플링(KNN) 등의 방법을 사용합니다.

# %% [markdown]
# ## 미션 2 - 머신러닝 알고리즘 모델을 통한 학습과 예측을 해주세요.
#
# * 강의에 있는 DecisionTree 를 사용해도 되며, 사이킷런의 다른 모델을 사용해도 됩니다.
# 다음과 같이 예측값이 나오도록 예측해 주세요.
# <font color="red"> 이탈여부의 Yes, No 는 예시로 다음의 결과와 달라도 상관 없습니다.</font>
#
# ```python
# # y_predict[:5] 를 출력했을 때 아래처럼 이탈 여부에 대한 값이 나옵니다.
# array(['No', 'No', 'No', 'No', 'No'], dtype=object)
# ```
#
# * 사이킷런에서 좋은 성능을 내고 주목받고 있는 알고리즘을 별도의 라이브러리로 공개되어 있는 것들이 다음과 같습니다.
#     * 부스팅계열 알고리즘(주로 정형 데이터) => XGBoost, LightGBM, CatBoost 등
#     * 신경망 알고리즘(주로 비정형 데이터) => TensorFlow, Keras, PyTorch 등
#
# * 알고리즘 중에는 분류, 회귀에 따로 사용할 수 있는 것도 있고, 분류, 회귀에 모두 사용할 수 있는 것도 있습니다.
#     * 회귀 알고리즘 => 분류(로지스틱 회귀), 회귀(릿지, 라쏘, 엘라스틱넷) 분류에 사용하는 알고리즘과 회귀에 사용하는게 다릅니다.
#     * 분류 및 회귀 트리(Classification And Regression Tree, CART) => 분류와 회귀에 모두 사용할 수 있습니다.
#
#
#
#
# * [참고 : 결정 트리 학습법 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EA%B2%B0%EC%A0%95_%ED%8A%B8%EB%A6%AC_%ED%95%99%EC%8A%B5%EB%B2%95)
#     * 결과를 해석하고 이해하기 쉽다.간략한 설명만으로 결정 트리를 이해하는 것이 가능하다.
#     * 자료를 가공할 필요가 거의 없다.다른 기법들의 경우 자료를 정규화하거나 임의의 변수를 생성하거나 값이 없는 변수를 제거해야 하는 경우가 있다.
#     * 수치 자료와 범주 자료 모두에 적용할 수 있다.다른 기법들은 일반적으로 오직 한 종류의 변수를 갖는 데이터 셋을 분석하는 것에 특화되어 있다. (일례로 신경망 학습은 숫자로 표현된 변수만을 다룰 수 있는 것에 반해 관계식(relation rules)은 오직 명목 변수만을 다룰 수 있다.
#     * 화이트박스 모델을 사용한다. 모델에서 주어진 상황이 관측 가능하다면 불 논리를 이용하여 조건에 대해 쉽게 설명할 수 있다. (결과에 대한 설명을 이해하기 어렵기 때문에 인공신경망은 대표적인 블랙 박스 모델이다.)
#     * 안정적이다. 해당 모델 추리의 기반이 되는 명제가 다소 손상되었더라도 잘 동작한다.
#     * 대규모의 데이터 셋에서도 잘 동작한다. 방대한 분량의 데이터를 일반적인 컴퓨터 환경에서 합리적인 시간 안에 분석할 수 있다.
#
#
# ```python
# DecisionTreeClassifier(
#     *,
#     criterion='gini', # 분할방법 {"gini", "entropy"}, default="gini"
#     splitter='best',
#     max_depth=None, # The maximum depth of the tree
#     min_samples_split=2, # The minimum number of samples required to split an internal node
#     min_samples_leaf=1, # The minimum number of samples required to be at a leaf node.
#     min_weight_fraction_leaf=0.0, # The minimum weighted fraction of the sum total of weights
#     max_features=None, # The number of features to consider when looking for the best split
#     random_state=None,
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     class_weight=None,
#     ccp_alpha=0.0,
# )
# ```
#
# * 주요 파라미터
#     * criterion: 가지의 분할의 품질을 측정하는 기능입니다.
#     * max_depth: 트리의 최대 깊이입니다.
#     * min_samples_split:내부 노드를 분할하는 데 필요한 최소 샘플 수입니다.
#     * min_samples_leaf: 리프 노드에 있어야 하는 최소 샘플 수입니다.
#     * max_leaf_nodes: 리프 노드 숫자의 제한치입니다.
#     * random_state: 추정기의 무작위성을 제어합니다. 실행했을 때 같은 결과가 나오도록 합니다.
#
#
# ```python
# # max_depth == 1 트리의 깊이를 의미합니다.
# # max_features == 0.9 라면 전체 피처의 90% 만 사용합니다.
# from sklearn.tree import DecisionTreeClassifier
#
# model = DecisionTreeClassifier(criterion="gini",
#                                max_depth=15,
#                                max_features=0.9,
#                                random_state=42)
# model
# ```

# %% [markdown]
# * 머신러닝 모델의 성능을 개선하는 방법
#     * 데이터 분할
#     * 데이터 전처리, 결측치 처리
#     * 피처 선택, 피처 엔지니어링(스케일링, 변환, 인코딩 등)
#     * 모델의 `파라미터 값을 변경하는 방법`
#
# * <font color="red">머신러닝 알고리즘 모델을 통한 학습과 예측을 해주세요.</font>

# %%
# 사이킷런(sklearn)에서 의사 결정 트리 분류모델(DecisionTreeClassifier)을 로드합니다.
# 위 설명에서 제시한 주요 파라미터의 설정을 변경해서 모델을 만들어 주세요.
# 기본값으로 모델을 만들어도 되며 여러 파라미터를 변경하는 방법으로 만들어도 됩니다.

from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

# %%
# 데이터를 머신러닝 모델로 학습(fit)합니다.
# 기출문제 X_train 와 기출문제의 정답 y_train 을 넣고 학습을 합니다.
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# 데이터를 머신러닝 모델로 예측(predict)합니다.
y_predict = model.predict(X_test)
y_predict[:5]
# Out:
# array(['Yes', 'Yes', 'Yes', 'No', 'No'], dtype=object)

# %% [markdown]
# ## 미션 3 - 점수 측정하고 피처의 중요도 시각화 하기
# * 예측한 데이터셋의 점수를 Accuracy로 측정하고 모델이 학습한 피처의 중요도를 시각화 해주세요.
# * 피처 중요도 이미지는 예시이며 다른 결과가 나와도 상관 없습니다. 또, 트리 계열 모델이 아닌 다른 모델로 학습했을 때도 해당 모델에 맞는 피처 중요도를 시각화 해주세요.
#
# ### 3-1) 트리 시각화 하기
#
# * 해당 이미지는 예시로 모델의 학습 결과에 따라 다르게 나올 수 있습니다.
#
# <img src="https://i.imgur.com/NgvuaC8.png" width="500">

# %%
# plot_tree 를 통해 tree 를 시각화 합니다.
# 시각화 할 때만 max_depth를 제한한것이고 실제 모델에서는 다른 값을 사용하게 됩니다.
# 위 예시 이미지를 참고합니다.
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 10))
# 여기에 구현해 주세요.
plot_tree(model, feature_names=feature_names, filled=True)
# Out:
# [Text(0.45097123705293907, 0.9833333333333333, 'tenure <= 16.5\ngini = 0.387\nsamples = 4922\nvalue = [3633, 1289]'),
#  Text(0.2337171343838527, 0.95, 'MonthlyCharges <= 69.525\ngini = 0.495\nsamples = 1785\nvalue = [985, 800]'),
#  Text(0.11506617386685553, 0.9166666666666666, 'tenure <= 2.5\ngini = 0.413\nsamples = 1007\nvalue = [713, 294]'),
#  Text(0.05290368271954674, 0.8833333333333333, 'MonthlyCharges <= 20.85\ngini = 0.497\nsamples = 371\nvalue = [200, 171]'),
#  Text(0.03128541076487252, 0.85, 'TotalCharges <= 20.275\ngini = 0.397\nsamples = 132\nvalue = [96, 36]'),
#  Text(0.015545325779036827, 0.8166666666666667, 'TotalCharges <= 19.275\ngini = 0.455\nsamples = 83\nvalue = [54, 29]'),
#  Text(0.0022662889518413596, 0.7833333333333333, 'PaperlessBilling_encode <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.0011331444759206798, 0.75, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.0033994334277620396, 0.75, 'MonthlyCharges <= 19.15\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.0022662889518413596, 0.7166666666666667, 'Partner_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0011331444759206798, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0033994334277620396, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.004532577903682719, 0.7166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.028824362606232296, 0.7833333333333333, 'Partner_encode <= 0.5\ngini = 0.478\nsamples = 71\nvalue = [43, 28]'),
#  Text(0.019121813031161474, 0.75, 'PaperlessBilling_encode <= 0.5\ngini = 0.489\nsamples = 61\nvalue = [35, 26]'),
#  Text(0.009915014164305949, 0.7166666666666667, 'MonthlyCharges <= 19.425\ngini = 0.464\nsamples = 41\nvalue = [26, 15]'),
#  Text(0.0056657223796034, 0.6833333333333333, 'TotalCharges <= 19.35\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.004532577903682719, 0.65, 'gender_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0033994334277620396, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0056657223796034, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.006798866855524079, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.014164305949008499, 0.6833333333333333, 'gender_encode <= 0.5\ngini = 0.45\nsamples = 38\nvalue = [25, 13]'),
#  Text(0.009065155807365438, 0.65, 'TotalCharges <= 19.525\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.00793201133144476, 0.6166666666666667, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.010198300283286119, 0.6166666666666667, 'TotalCharges <= 19.6\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.009065155807365438, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0113314447592068, 0.5833333333333334, 'MonthlyCharges <= 19.7\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.010198300283286119, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.012464589235127478, 0.55, 'TotalCharges <= 19.875\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.0113314447592068, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.013597733711048159, 0.5166666666666667, 'TotalCharges <= 19.925\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.012464589235127478, 0.48333333333333334, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.014730878186968839, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.019263456090651557, 0.65, 'MonthlyCharges <= 19.5\ngini = 0.486\nsamples = 24\nvalue = [14, 10]'),
#  Text(0.018130311614730877, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.020396600566572238, 0.6166666666666667, 'TotalCharges <= 20.175\ngini = 0.496\nsamples = 22\nvalue = [12, 10]'),
#  Text(0.018130311614730877, 0.5833333333333334, 'MonthlyCharges <= 20.075\ngini = 0.498\nsamples = 17\nvalue = [8, 9]'),
#  Text(0.0169971671388102, 0.55, 'MonthlyCharges <= 19.6\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.01586402266288952, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.018130311614730877, 0.5166666666666667, 'TotalCharges <= 19.7\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.0169971671388102, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.019263456090651557, 0.48333333333333334, 'TotalCharges <= 19.825\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.0169971671388102, 0.45, 'Dependents_encode <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.01586402266288952, 0.4166666666666667, 'MonthlyCharges <= 19.775\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.014730878186968839, 0.38333333333333336, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0169971671388102, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.018130311614730877, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.02152974504249292, 0.45, 'Dependents_encode <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.020396600566572238, 0.4166666666666667, 'TotalCharges <= 20.025\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.019263456090651557, 0.38333333333333336, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.02152974504249292, 0.38333333333333336, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0226628895184136, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.019263456090651557, 0.55, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.0226628895184136, 0.5833333333333334, 'TotalCharges <= 20.225\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.02152974504249292, 0.55, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.02379603399433428, 0.55, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.028328611898016998, 0.7166666666666667, 'MonthlyCharges <= 19.475\ngini = 0.495\nsamples = 20\nvalue = [9, 11]'),
#  Text(0.027195467422096317, 0.6833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.029461756373937678, 0.6833333333333333, 'TotalCharges <= 19.575\ngini = 0.5\nsamples = 18\nvalue = [9, 9]'),
#  Text(0.028328611898016998, 0.65, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.03059490084985836, 0.65, 'Dependents_encode <= 0.5\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.029461756373937678, 0.6166666666666667, 'TotalCharges <= 19.8\ngini = 0.459\nsamples = 14\nvalue = [5, 9]'),
#  Text(0.027195467422096317, 0.5833333333333334, 'TotalCharges <= 19.625\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.026062322946175637, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.028328611898016998, 0.55, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.03172804532577904, 0.5833333333333334, 'TotalCharges <= 20.225\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.03059490084985836, 0.55, 'MonthlyCharges <= 20.075\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.029461756373937678, 0.5166666666666667, 'TotalCharges <= 19.975\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.028328611898016998, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03059490084985836, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03172804532577904, 0.5166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.03286118980169972, 0.55, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03172804532577904, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.038526912181303115, 0.75, 'MonthlyCharges <= 19.975\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.037393767705382434, 0.7166666666666667, 'TotalCharges <= 19.9\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.036260623229461754, 0.6833333333333333, 'MonthlyCharges <= 19.55\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.03512747875354107, 0.65, 'TotalCharges <= 19.425\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0339943342776204, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.036260623229461754, 0.6166666666666667, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.037393767705382434, 0.65, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.038526912181303115, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.039660056657223795, 0.7166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.04702549575070822, 0.8166666666666667, 'MonthlyCharges <= 20.475\ngini = 0.245\nsamples = 49\nvalue = [42, 7]'),
#  Text(0.04419263456090652, 0.7833333333333333, 'MonthlyCharges <= 19.875\ngini = 0.149\nsamples = 37\nvalue = [34, 3]'),
#  Text(0.04305949008498584, 0.75, 'TotalCharges <= 36.55\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.041926345609065156, 0.7166666666666667, 'TotalCharges <= 27.925\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.040793201133144476, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04305949008498584, 0.6833333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.04419263456090652, 0.7166666666666667, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.0453257790368272, 0.75, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.04985835694050991, 0.7833333333333333, 'TotalCharges <= 20.6\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.04759206798866856, 0.75, 'Dependents_encode <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.04645892351274788, 0.7166666666666667, 'gender_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0453257790368272, 0.6833333333333333, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04759206798866856, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04872521246458923, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05212464589235127, 0.75, 'TotalCharges <= 36.15\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.05099150141643059, 0.7166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.053257790368271954, 0.7166666666666667, 'TotalCharges <= 39.275\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05212464589235127, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.054390934844192634, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07452195467422096, 0.85, 'MonthlyCharges <= 64.95\ngini = 0.492\nsamples = 239\nvalue = [104, 135]'),
#  Text(0.0722556657223796, 0.8166666666666667, 'TotalCharges <= 116.075\ngini = 0.497\nsamples = 224\nvalue = [103, 121]'),
#  Text(0.07112252124645892, 0.7833333333333333, 'PhoneService_encode <= 0.5\ngini = 0.493\nsamples = 217\nvalue = [96, 121]'),
#  Text(0.058923512747875356, 0.75, 'MonthlyCharges <= 34.15\ngini = 0.413\nsamples = 55\nvalue = [16, 39]'),
#  Text(0.057790368271954676, 0.7166666666666667, 'SeniorCitizen <= 0.5\ngini = 0.48\nsamples = 40\nvalue = [16, 24]'),
#  Text(0.056657223796033995, 0.6833333333333333, 'PaperlessBilling_encode <= 0.5\ngini = 0.5\nsamples = 32\nvalue = [16, 16]'),
#  Text(0.05099150141643059, 0.65, 'TotalCharges <= 25.225\ngini = 0.465\nsamples = 19\nvalue = [12, 7]'),
#  Text(0.04872521246458923, 0.6166666666666667, 'MonthlyCharges <= 24.725\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.04759206798866856, 0.5833333333333334, 'TotalCharges <= 24.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.04645892351274788, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04872521246458923, 0.55, 'MonthlyCharges <= 24.65\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04759206798866856, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04985835694050991, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04985835694050991, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.053257790368271954, 0.6166666666666667, 'MonthlyCharges <= 29.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.05212464589235127, 0.5833333333333334, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.054390934844192634, 0.5833333333333334, 'MonthlyCharges <= 30.375\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.053257790368271954, 0.55, 'TotalCharges <= 29.925\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.05212464589235127, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.054390934844192634, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.055524079320113315, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06232294617563739, 0.65, 'TotalCharges <= 61.4\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(0.06118980169971672, 0.6166666666666667, 'TotalCharges <= 30.6\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.06005665722379604, 0.5833333333333334, 'MonthlyCharges <= 27.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.058923512747875356, 0.55, 'MonthlyCharges <= 24.425\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.056657223796033995, 0.5166666666666667, 'TotalCharges <= 24.325\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.055524079320113315, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.057790368271954676, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06118980169971672, 0.5166666666666667, 'TotalCharges <= 25.125\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.06005665722379604, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.06232294617563739, 0.48333333333333334, 'gender_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06118980169971672, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06345609065155808, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06118980169971672, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06232294617563739, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.06345609065155808, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.058923512747875356, 0.6833333333333333, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.06005665722379604, 0.7166666666666667, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.08332152974504249, 0.75, 'TotalCharges <= 45.025\ngini = 0.5\nsamples = 162\nvalue = [80, 82]'),
#  Text(0.07138810198300283, 0.7166666666666667, 'TotalCharges <= 21.025\ngini = 0.418\nsamples = 37\nvalue = [26, 11]'),
#  Text(0.0679886685552408, 0.6833333333333333, 'gender_encode <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.06685552407932012, 0.65, 'MonthlyCharges <= 20.925\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.06572237960339944, 0.6166666666666667, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0679886685552408, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06912181303116147, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07478753541076487, 0.6833333333333333, 'MonthlyCharges <= 44.725\ngini = 0.35\nsamples = 31\nvalue = [24, 7]'),
#  Text(0.07365439093484419, 0.65, 'MonthlyCharges <= 44.1\ngini = 0.403\nsamples = 25\nvalue = [18, 7]'),
#  Text(0.07025495750708215, 0.6166666666666667, 'PaperlessBilling_encode <= 0.5\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.06912181303116147, 0.5833333333333334, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.07138810198300283, 0.5833333333333334, 'MonthlyCharges <= 43.375\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.07025495750708215, 0.55, 'TotalCharges <= 34.325\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.06912181303116147, 0.5166666666666667, 'MonthlyCharges <= 24.525\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.0679886685552408, 0.48333333333333334, 'TotalCharges <= 22.55\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06685552407932012, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06912181303116147, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07025495750708215, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07138810198300283, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07252124645892351, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07705382436260623, 0.6166666666666667, 'PaperlessBilling_encode <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.07592067988668555, 0.5833333333333334, 'MonthlyCharges <= 44.65\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.07478753541076487, 0.55, 'MonthlyCharges <= 44.425\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.07365439093484419, 0.5166666666666667, 'TotalCharges <= 44.275\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07252124645892351, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07478753541076487, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07592067988668555, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07705382436260623, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07818696883852691, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07592067988668555, 0.65, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.09525495750708216, 0.7166666666666667, 'TotalCharges <= 46.25\ngini = 0.491\nsamples = 125\nvalue = [54, 71]'),
#  Text(0.08555240793201133, 0.6833333333333333, 'MonthlyCharges <= 45.625\ngini = 0.375\nsamples = 28\nvalue = [7, 21]'),
#  Text(0.08158640226628895, 0.65, 'MonthlyCharges <= 45.175\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.08045325779036827, 0.6166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.08271954674220963, 0.6166666666666667, 'PaperlessBilling_encode <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.08045325779036827, 0.5833333333333334, 'TotalCharges <= 45.275\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.07932011331444759, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08158640226628895, 0.55, 'gender_encode <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.08045325779036827, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08271954674220963, 0.5166666666666667, 'TotalCharges <= 45.45\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08158640226628895, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08385269121813031, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08498583569405099, 0.5833333333333334, 'MonthlyCharges <= 45.475\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.08385269121813031, 0.55, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.08611898016997167, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08951841359773371, 0.65, 'MonthlyCharges <= 45.775\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.08838526912181303, 0.6166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.0906515580736544, 0.6166666666666667, 'TotalCharges <= 45.825\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.08951841359773371, 0.5833333333333334, 'gender_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08838526912181303, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0906515580736544, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09178470254957508, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.10495750708215297, 0.6833333333333333, 'TotalCharges <= 50.3\ngini = 0.5\nsamples = 97\nvalue = [47, 50]'),
#  Text(0.09915014164305949, 0.65, 'SeniorCitizen <= 0.5\ngini = 0.375\nsamples = 24\nvalue = [18, 6]'),
#  Text(0.09631728045325778, 0.6166666666666667, 'TotalCharges <= 48.65\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.09405099150141644, 0.5833333333333334, 'TotalCharges <= 47.125\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.09291784702549576, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09518413597733712, 0.55, 'TotalCharges <= 48.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09405099150141644, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09631728045325778, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09858356940509914, 0.5833333333333334, 'MonthlyCharges <= 49.925\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.09745042492917846, 0.55, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.09971671388101983, 0.55, 'MonthlyCharges <= 50.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.09858356940509914, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1008498583569405, 0.5166666666666667, 'TotalCharges <= 50.125\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.09971671388101983, 0.48333333333333334, 'gender_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.09858356940509914, 0.45, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1008498583569405, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10198300283286119, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.10198300283286119, 0.6166666666666667, 'MonthlyCharges <= 47.925\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1008498583569405, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10311614730878187, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11076487252124646, 0.65, 'TotalCharges <= 55.025\ngini = 0.479\nsamples = 73\nvalue = [29, 44]'),
#  Text(0.10651558073654391, 0.6166666666666667, 'PaperlessBilling_encode <= 0.5\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.10538243626062323, 0.5833333333333334, 'TotalCharges <= 50.7\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.10424929178470255, 0.55, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.10651558073654391, 0.55, 'gender_encode <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.10538243626062323, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10764872521246459, 0.5166666666666667, 'TotalCharges <= 50.775\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.10651558073654391, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10878186968838527, 0.48333333333333334, 'MonthlyCharges <= 51.075\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.10764872521246459, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.10991501416430595, 0.45, 'MonthlyCharges <= 52.8\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10878186968838527, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11104815864022663, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10764872521246459, 0.5833333333333334, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.115014164305949, 0.6166666666666667, 'TotalCharges <= 55.675\ngini = 0.5\nsamples = 53\nvalue = [26, 27]'),
#  Text(0.11218130311614731, 0.5833333333333334, 'TotalCharges <= 55.225\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.11104815864022663, 0.55, 'TotalCharges <= 55.125\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10991501416430595, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11218130311614731, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11331444759206799, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.11784702549575071, 0.5833333333333334, 'MonthlyCharges <= 60.5\ngini = 0.494\nsamples = 47\nvalue = [21, 26]'),
#  Text(0.11558073654390935, 0.55, 'MonthlyCharges <= 59.7\ngini = 0.482\nsamples = 42\nvalue = [17, 25]'),
#  Text(0.11444759206798867, 0.5166666666666667, 'TotalCharges <= 59.375\ngini = 0.492\nsamples = 39\nvalue = [17, 22]'),
#  Text(0.11331444759206799, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11558073654390935, 0.48333333333333334, 'Dependents_encode <= 0.5\ngini = 0.497\nsamples = 37\nvalue = [17, 20]'),
#  Text(0.11444759206798867, 0.45, 'TotalCharges <= 114.425\ngini = 0.49\nsamples = 35\nvalue = [15, 20]'),
#  Text(0.11331444759206799, 0.4166666666666667, 'TotalCharges <= 108.7\ngini = 0.496\nsamples = 33\nvalue = [15, 18]'),
#  Text(0.11048158640226628, 0.38333333333333336, 'MonthlyCharges <= 54.65\ngini = 0.485\nsamples = 29\nvalue = [12, 17]'),
#  Text(0.10934844192634562, 0.35, 'gender_encode <= 0.5\ngini = 0.494\nsamples = 27\nvalue = [12, 15]'),
#  Text(0.1048158640226629, 0.31666666666666665, 'MonthlyCharges <= 47.45\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.10254957507082153, 0.2833333333333333, 'TotalCharges <= 80.75\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.10141643059490085, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10368271954674221, 0.25, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.10708215297450425, 0.2833333333333333, 'PaperlessBilling_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.10594900849858357, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10821529745042494, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11388101983002832, 0.31666666666666665, 'MonthlyCharges <= 46.3\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(0.11161473087818696, 0.2833333333333333, 'MonthlyCharges <= 34.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.11048158640226628, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11274787535410764, 0.25, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.11614730878186968, 0.2833333333333333, 'TotalCharges <= 107.625\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.115014164305949, 0.25, 'MonthlyCharges <= 49.6\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.11388101983002832, 0.21666666666666667, 'PaperlessBilling_encode <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.11274787535410764, 0.18333333333333332, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.115014164305949, 0.18333333333333332, 'MonthlyCharges <= 47.2\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11388101983002832, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11614730878186968, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11614730878186968, 0.21666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.11728045325779037, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11161473087818696, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11614730878186968, 0.38333333333333336, 'TotalCharges <= 112.575\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.115014164305949, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11728045325779037, 0.35, 'MonthlyCharges <= 56.7\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11614730878186968, 0.31666666666666665, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11841359773371105, 0.31666666666666665, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11558073654390935, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11671388101983003, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11671388101983003, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.12011331444759207, 0.55, 'TotalCharges <= 62.425\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.11898016997167139, 0.5166666666666667, 'MonthlyCharges <= 61.6\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11784702549575071, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12011331444759207, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12124645892351275, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07338881019830028, 0.7833333333333333, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.07678824362606232, 0.8166666666666667, 'TotalCharges <= 144.075\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.07565509915014164, 0.7833333333333333, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.077921388101983, 0.7833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17722866501416432, 0.8833333333333333, 'MonthlyCharges <= 20.925\ngini = 0.312\nsamples = 636\nvalue = [513, 123]'),
#  Text(0.13350743626062322, 0.85, 'TotalCharges <= 77.55\ngini = 0.151\nsamples = 231\nvalue = [212, 19]'),
#  Text(0.12577903682719546, 0.8166666666666667, 'TotalCharges <= 77.225\ngini = 0.305\nsamples = 32\nvalue = [26, 6]'),
#  Text(0.12464589235127478, 0.7833333333333333, 'TotalCharges <= 51.575\ngini = 0.271\nsamples = 31\nvalue = [26, 5]'),
#  Text(0.12237960339943343, 0.75, 'MonthlyCharges <= 20.275\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12124645892351275, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1235127478753541, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12691218130311616, 0.75, 'gender_encode <= 0.5\ngini = 0.238\nsamples = 29\nvalue = [25, 4]'),
#  Text(0.12577903682719546, 0.7166666666666667, 'TotalCharges <= 73.775\ngini = 0.346\nsamples = 18\nvalue = [14, 4]'),
#  Text(0.12464589235127478, 0.6833333333333333, 'MonthlyCharges <= 19.925\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.1235127478753541, 0.65, 'TotalCharges <= 58.025\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.12237960339943343, 0.6166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.12464589235127478, 0.6166666666666667, 'MonthlyCharges <= 19.7\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.1235127478753541, 0.5833333333333334, 'PaperlessBilling_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.12237960339943343, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12464589235127478, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12577903682719546, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12577903682719546, 0.65, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.12691218130311616, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12804532577903682, 0.7166666666666667, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.12691218130311616, 0.7833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.141235835694051, 0.8166666666666667, 'MonthlyCharges <= 19.275\ngini = 0.122\nsamples = 199\nvalue = [186, 13]'),
#  Text(0.13257790368271954, 0.7833333333333333, 'MonthlyCharges <= 19.225\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.13144475920679888, 0.75, 'TotalCharges <= 174.4\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.13031161473087818, 0.7166666666666667, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.13257790368271954, 0.7166666666666667, 'TotalCharges <= 244.55\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.13144475920679888, 0.6833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13371104815864024, 0.6833333333333333, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.13371104815864024, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.14989376770538243, 0.7833333333333333, 'SeniorCitizen <= 0.5\ngini = 0.093\nsamples = 184\nvalue = [175, 9]'),
#  Text(0.14596317280453258, 0.75, 'TotalCharges <= 341.875\ngini = 0.076\nsamples = 178\nvalue = [171, 7]'),
#  Text(0.1415014164305949, 0.7166666666666667, 'gender_encode <= 0.5\ngini = 0.066\nsamples = 176\nvalue = [170, 6]'),
#  Text(0.1359773371104816, 0.6833333333333333, 'MonthlyCharges <= 20.025\ngini = 0.106\nsamples = 89\nvalue = [84, 5]'),
#  Text(0.1348441926345609, 0.65, 'MonthlyCharges <= 19.725\ngini = 0.198\nsamples = 45\nvalue = [40, 5]'),
#  Text(0.1311614730878187, 0.6166666666666667, 'MonthlyCharges <= 19.425\ngini = 0.077\nsamples = 25\nvalue = [24, 1]'),
#  Text(0.13002832861189803, 0.5833333333333334, 'tenure <= 14.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.12889518413597734, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1311614730878187, 0.55, 'tenure <= 15.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13002832861189803, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13229461756373936, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13229461756373936, 0.5833333333333334, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.1385269121813031, 0.6166666666666667, 'MonthlyCharges <= 19.775\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.13456090651558072, 0.5833333333333334, 'TotalCharges <= 177.825\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.13342776203966006, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13569405099150142, 0.55, 'TotalCharges <= 253.975\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13456090651558072, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13682719546742209, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1424929178470255, 0.5833333333333334, 'TotalCharges <= 220.775\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.14022662889518414, 0.55, 'TotalCharges <= 139.6\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.13909348441926345, 0.5166666666666667, 'TotalCharges <= 128.45\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.13796033994334278, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14022662889518414, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1413597733711048, 0.5166666666666667, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.14475920679886686, 0.55, 'tenure <= 13.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.14362606232294617, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14589235127478753, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.13711048158640227, 0.65, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(0.14702549575070822, 0.6833333333333333, 'MonthlyCharges <= 20.225\ngini = 0.023\nsamples = 87\nvalue = [86, 1]'),
#  Text(0.14589235127478753, 0.65, 'gini = 0.0\nsamples = 60\nvalue = [60, 0]'),
#  Text(0.1481586402266289, 0.65, 'MonthlyCharges <= 20.3\ngini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(0.14702549575070822, 0.6166666666666667, 'TotalCharges <= 176.6\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.14589235127478753, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1481586402266289, 0.5833333333333334, 'TotalCharges <= 193.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14702549575070822, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14929178470254958, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14929178470254958, 0.6166666666666667, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.15042492917847025, 0.7166666666666667, 'TotalCharges <= 351.375\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14929178470254958, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15155807365439095, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1538243626062323, 0.75, 'TotalCharges <= 135.55\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.1526912181303116, 0.7166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.15495750708215297, 0.7166666666666667, 'tenure <= 12.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1538243626062323, 0.6833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15609065155807367, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.22094989376770538, 0.85, 'TotalCharges <= 311.05\ngini = 0.382\nsamples = 405\nvalue = [301, 104]'),
#  Text(0.1911827195467422, 0.8166666666666667, 'MonthlyCharges <= 55.525\ngini = 0.453\nsamples = 179\nvalue = [117, 62]'),
#  Text(0.17613314447592068, 0.7833333333333333, 'MonthlyCharges <= 30.75\ngini = 0.473\nsamples = 154\nvalue = [95, 59]'),
#  Text(0.16175637393767706, 0.75, 'TotalCharges <= 70.025\ngini = 0.391\nsamples = 60\nvalue = [44, 16]'),
#  Text(0.16062322946175636, 0.7166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.16288951841359772, 0.7166666666666667, 'TotalCharges <= 245.175\ngini = 0.366\nsamples = 58\nvalue = [44, 14]'),
#  Text(0.158356940509915, 0.6833333333333333, 'MonthlyCharges <= 21.125\ngini = 0.287\nsamples = 46\nvalue = [38, 8]'),
#  Text(0.15609065155807367, 0.65, 'tenure <= 5.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.15495750708215297, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15722379603399433, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16062322946175636, 0.65, 'PhoneService_encode <= 0.5\ngini = 0.245\nsamples = 42\nvalue = [36, 6]'),
#  Text(0.1594900849858357, 0.6166666666666667, 'MonthlyCharges <= 29.425\ngini = 0.365\nsamples = 25\nvalue = [19, 6]'),
#  Text(0.158356940509915, 0.5833333333333334, 'SeniorCitizen <= 0.5\ngini = 0.457\nsamples = 17\nvalue = [11, 6]'),
#  Text(0.15722379603399433, 0.55, 'MonthlyCharges <= 24.525\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.15495750708215297, 0.5166666666666667, 'TotalCharges <= 98.125\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1538243626062323, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15609065155807367, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1594900849858357, 0.5166666666666667, 'gender_encode <= 0.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.158356940509915, 0.48333333333333334, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.16062322946175636, 0.48333333333333334, 'Dependents_encode <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.1594900849858357, 0.45, 'Partner_encode <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.158356940509915, 0.4166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.16062322946175636, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16175637393767706, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1594900849858357, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.16062322946175636, 0.5833333333333334, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.16175637393767706, 0.6166666666666667, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.16742209631728044, 0.6833333333333333, 'TotalCharges <= 263.575\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.16515580736543908, 0.65, 'PhoneService_encode <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.16402266288951842, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.16628895184135978, 0.6166666666666667, 'tenure <= 10.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16515580736543908, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16742209631728044, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1696883852691218, 0.65, 'TotalCharges <= 300.75\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.16855524079320114, 0.6166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1708215297450425, 0.6166666666666667, 'tenure <= 11.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1696883852691218, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17195467422096317, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1905099150141643, 0.75, 'MonthlyCharges <= 34.075\ngini = 0.496\nsamples = 94\nvalue = [51, 43]'),
#  Text(0.18937677053824362, 0.7166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.19164305949008498, 0.7166666666666667, 'TotalCharges <= 201.575\ngini = 0.493\nsamples = 91\nvalue = [51, 40]'),
#  Text(0.18158640226628894, 0.6833333333333333, 'TotalCharges <= 164.375\ngini = 0.498\nsamples = 43\nvalue = [20, 23]'),
#  Text(0.17762039660056658, 0.65, 'SeniorCitizen <= 0.5\ngini = 0.483\nsamples = 27\nvalue = [16, 11]'),
#  Text(0.1764872521246459, 0.6166666666666667, 'MonthlyCharges <= 50.55\ngini = 0.444\nsamples = 24\nvalue = [16, 8]'),
#  Text(0.17422096317280453, 0.5833333333333334, 'TotalCharges <= 141.6\ngini = 0.375\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.17308781869688386, 0.55, 'TotalCharges <= 138.3\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.17195467422096317, 0.5166666666666667, 'TotalCharges <= 108.1\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.1708215297450425, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.17308781869688386, 0.48333333333333334, 'TotalCharges <= 135.125\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.17195467422096317, 0.45, 'PaperlessBilling_encode <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.1708215297450425, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17308781869688386, 0.4166666666666667, 'gender_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.17195467422096317, 0.38333333333333336, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17422096317280453, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17422096317280453, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17422096317280453, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17535410764872522, 0.55, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.17875354107648725, 0.5833333333333334, 'TotalCharges <= 145.85\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.17762039660056658, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17988668555240794, 0.55, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.17875354107648725, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.18555240793201133, 0.65, 'Partner_encode <= 0.5\ngini = 0.375\nsamples = 16\nvalue = [4, 12]'),
#  Text(0.18441926345609067, 0.6166666666666667, 'SeniorCitizen <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.18328611898016997, 0.5833333333333334, 'gender_encode <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.1821529745042493, 0.55, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.18441926345609067, 0.55, 'TotalCharges <= 175.25\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.18328611898016997, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.18555240793201133, 0.5166666666666667, 'TotalCharges <= 188.9\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.18441926345609067, 0.48333333333333334, 'tenure <= 3.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.18328611898016997, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18555240793201133, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.186685552407932, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.18555240793201133, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.186685552407932, 0.6166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.201699716713881, 0.6833333333333333, 'MonthlyCharges <= 50.9\ngini = 0.457\nsamples = 48\nvalue = [31, 17]'),
#  Text(0.19943342776203965, 0.65, 'TotalCharges <= 204.45\ngini = 0.488\nsamples = 38\nvalue = [22, 16]'),
#  Text(0.19830028328611898, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.20056657223796034, 0.6166666666666667, 'TotalCharges <= 295.325\ngini = 0.496\nsamples = 35\nvalue = [19, 16]'),
#  Text(0.19943342776203965, 0.5833333333333334, 'PaperlessBilling_encode <= 0.5\ngini = 0.5\nsamples = 32\nvalue = [16, 16]'),
#  Text(0.19405099150141644, 0.55, 'tenure <= 6.5\ngini = 0.48\nsamples = 20\nvalue = [12, 8]'),
#  Text(0.19291784702549575, 0.5166666666666667, 'TotalCharges <= 221.95\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(0.19008498583569405, 0.48333333333333334, 'TotalCharges <= 212.65\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.1878186968838527, 0.45, 'TotalCharges <= 207.525\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.186685552407932, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18895184135977336, 0.4166666666666667, 'PhoneService_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1878186968838527, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19008498583569405, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19235127478753541, 0.45, 'MonthlyCharges <= 47.375\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.19121813031161472, 0.4166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.19348441926345608, 0.4166666666666667, 'TotalCharges <= 218.375\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.19235127478753541, 0.38333333333333336, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.19461756373937678, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19575070821529744, 0.48333333333333334, 'TotalCharges <= 242.15\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.19461756373937678, 0.45, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.19688385269121814, 0.45, 'MonthlyCharges <= 47.4\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.19575070821529744, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1980169971671388, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1951841359773371, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.20481586402266289, 0.55, 'MonthlyCharges <= 49.05\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.20368271954674222, 0.5166666666666667, 'MonthlyCharges <= 46.625\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.20254957507082152, 0.48333333333333334, 'SeniorCitizen <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.20141643059490086, 0.45, 'MonthlyCharges <= 37.8\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.20028328611898016, 0.4166666666666667, 'MonthlyCharges <= 35.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1991501416430595, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20141643059490086, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20254957507082152, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.20368271954674222, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20481586402266289, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20594900849858358, 0.5166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.201699716713881, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.20396600566572237, 0.65, 'TotalCharges <= 307.925\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.2028328611898017, 0.6166666666666667, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.20509915014164307, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20623229461756373, 0.7833333333333333, 'Dependents_encode <= 0.5\ngini = 0.211\nsamples = 25\nvalue = [22, 3]'),
#  Text(0.20396600566572237, 0.75, 'MonthlyCharges <= 67.125\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.2028328611898017, 0.7166666666666667, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.20509915014164307, 0.7166666666666667, 'TotalCharges <= 261.45\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.20396600566572237, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20623229461756373, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2084985835694051, 0.75, 'gender_encode <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.20736543909348443, 0.7166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2096317280453258, 0.7166666666666667, 'MonthlyCharges <= 56.025\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.2084985835694051, 0.6833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21076487252124645, 0.6833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.25071706798866855, 0.8166666666666667, 'TotalCharges <= 890.825\ngini = 0.303\nsamples = 226\nvalue = [184, 42]'),
#  Text(0.2289128895184136, 0.7833333333333333, 'MonthlyCharges <= 40.6\ngini = 0.271\nsamples = 210\nvalue = [176, 34]'),
# ...
#  Text(0.384985835694051, 0.25, 'MonthlyCharges <= 82.95\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3838526912181303, 0.21666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.38611898016997165, 0.21666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38611898016997165, 0.2833333333333333, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.3671388101983003, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36827195467422097, 0.48333333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.36940509915014164, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36940509915014164, 0.65, 'Dependents_encode <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.36827195467422097, 0.6166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3705382436260623, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.375070821529745, 0.6833333333333333, 'tenure <= 5.5\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.37393767705382436, 0.65, 'TotalCharges <= 382.2\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3728045325779037, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.375070821529745, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37620396600566575, 0.65, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.39525495750708217, 0.8166666666666667, 'MonthlyCharges <= 70.75\ngini = 0.472\nsamples = 105\nvalue = [65, 40]'),
#  Text(0.39412181303116145, 0.7833333333333333, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.39638810198300284, 0.7833333333333333, 'SeniorCitizen <= 0.5\ngini = 0.485\nsamples = 97\nvalue = [57, 40]'),
#  Text(0.3902266288951841, 0.75, 'TotalCharges <= 1112.075\ngini = 0.463\nsamples = 77\nvalue = [49, 28]'),
#  Text(0.38470254957507083, 0.7166666666666667, 'TotalCharges <= 1056.7\ngini = 0.495\nsamples = 51\nvalue = [28, 23]'),
#  Text(0.38356940509915016, 0.6833333333333333, 'TotalCharges <= 954.475\ngini = 0.47\nsamples = 45\nvalue = [28, 17]'),
#  Text(0.3793201133144476, 0.65, 'TotalCharges <= 938.675\ngini = 0.499\nsamples = 29\nvalue = [15, 14]'),
#  Text(0.3781869688385269, 0.6166666666666667, 'PaperlessBilling_encode <= 0.5\ngini = 0.494\nsamples = 27\nvalue = [15, 12]'),
#  Text(0.37308781869688384, 0.5833333333333334, 'TotalCharges <= 816.975\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.3719546742209632, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3742209631728045, 0.55, 'MonthlyCharges <= 80.275\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.37308781869688384, 0.5166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.37535410764872523, 0.5166666666666667, 'tenure <= 11.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3742209631728045, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3764872521246459, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38328611898016995, 0.5833333333333334, 'TotalCharges <= 928.325\ngini = 0.499\nsamples = 19\nvalue = [9, 10]'),
#  Text(0.3821529745042493, 0.55, 'TotalCharges <= 867.45\ngini = 0.484\nsamples = 17\nvalue = [7, 10]'),
#  Text(0.37988668555240795, 0.5166666666666667, 'TotalCharges <= 844.875\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.37875354107648723, 0.48333333333333334, 'TotalCharges <= 810.2\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.37762039660056657, 0.45, 'MonthlyCharges <= 73.825\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3764872521246459, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.37875354107648723, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.37988668555240795, 0.45, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3810198300283286, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3844192634560907, 0.5166666666666667, 'Dependents_encode <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.38328611898016995, 0.48333333333333334, 'MonthlyCharges <= 71.475\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.3821529745042493, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3844192634560907, 0.45, 'TotalCharges <= 925.6\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.38328611898016995, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.38555240793201134, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38555240793201134, 0.48333333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3844192634560907, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.38045325779036826, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3878186968838527, 0.65, 'MonthlyCharges <= 75.725\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.386685552407932, 0.6166666666666667, 'MonthlyCharges <= 74.825\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.38555240793201134, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3878186968838527, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3889518413597734, 0.6166666666666667, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.3858356940509915, 0.6833333333333333, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.39575070821529745, 0.7166666666666667, 'TotalCharges <= 1305.525\ngini = 0.311\nsamples = 26\nvalue = [21, 5]'),
#  Text(0.39348441926345606, 0.6833333333333333, 'MonthlyCharges <= 74.2\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.3923512747875354, 0.65, 'MonthlyCharges <= 72.025\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.39121813031161473, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39348441926345606, 0.6166666666666667, 'Dependents_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3923512747875354, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3946175637393768, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3946175637393768, 0.65, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.3980169971671388, 0.6833333333333333, 'PaperlessBilling_encode <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3968838526912181, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3991501416430595, 0.65, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.4025495750708215, 0.75, 'TotalCharges <= 893.45\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.40141643059490084, 0.7166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.40368271954674223, 0.7166666666666667, 'TotalCharges <= 1370.65\ngini = 0.375\nsamples = 16\nvalue = [4, 12]'),
#  Text(0.4025495750708215, 0.6833333333333333, 'TotalCharges <= 1066.2\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.40141643059490084, 0.65, 'MonthlyCharges <= 80.4\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.4002832861189802, 0.6166666666666667, 'MonthlyCharges <= 75.025\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.3991501416430595, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.40141643059490084, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4025495750708215, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.40368271954674223, 0.65, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4048158640226629, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4404390934844193, 0.85, 'PaperlessBilling_encode <= 0.5\ngini = 0.41\nsamples = 261\nvalue = [75, 186]'),
#  Text(0.42195467422096317, 0.8166666666666667, 'Partner_encode <= 0.5\ngini = 0.5\nsamples = 47\nvalue = [24, 23]'),
#  Text(0.41529745042492916, 0.7833333333333333, 'TotalCharges <= 339.625\ngini = 0.478\nsamples = 33\nvalue = [13, 20]'),
#  Text(0.4104815864022663, 0.75, 'gender_encode <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.40821529745042495, 0.7166666666666667, 'MonthlyCharges <= 92.45\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.40708215297450423, 0.6833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4093484419263456, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4127478753541077, 0.7166666666666667, 'Dependents_encode <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.41161473087818695, 0.6833333333333333, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.41388101983002834, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4201133144475921, 0.75, 'MonthlyCharges <= 89.3\ngini = 0.386\nsamples = 23\nvalue = [6, 17]'),
#  Text(0.4172804532577904, 0.7166666666666667, 'MonthlyCharges <= 87.7\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.4161473087818697, 0.6833333333333333, 'TotalCharges <= 763.3\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.415014164305949, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4172804532577904, 0.65, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.41841359773371106, 0.6833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4229461756373938, 0.7166666666666667, 'MonthlyCharges <= 105.2\ngini = 0.278\nsamples = 18\nvalue = [3, 15]'),
#  Text(0.42181303116147306, 0.6833333333333333, 'Dependents_encode <= 0.5\ngini = 0.208\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.41954674220963173, 0.65, 'tenure <= 11.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.41841359773371106, 0.6166666666666667, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.4206798866855524, 0.6166666666666667, 'TotalCharges <= 1207.125\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.41954674220963173, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.42181303116147306, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.42407932011331445, 0.65, 'TotalCharges <= 617.95\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4229461756373938, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4252124645892351, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.42407932011331445, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4286118980169972, 0.7833333333333333, 'MonthlyCharges <= 90.175\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.4263456090651558, 0.75, 'Dependents_encode <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.4252124645892351, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4274787535410765, 0.7166666666666667, 'tenure <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4263456090651558, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4286118980169972, 0.6833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4308781869688385, 0.75, 'MonthlyCharges <= 100.925\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.42974504249291784, 0.7166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.43201133144475923, 0.7166666666666667, 'MonthlyCharges <= 101.45\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.4308781869688385, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4331444759206799, 0.6833333333333333, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.45892351274787535, 0.8166666666666667, 'MonthlyCharges <= 95.95\ngini = 0.363\nsamples = 214\nvalue = [51, 163]'),
#  Text(0.44575070821529744, 0.7833333333333333, 'TotalCharges <= 507.425\ngini = 0.406\nsamples = 141\nvalue = [40, 101]'),
#  Text(0.4405099150141643, 0.75, 'gender_encode <= 0.5\ngini = 0.289\nsamples = 57\nvalue = [10, 47]'),
#  Text(0.43654390934844195, 0.7166666666666667, 'MonthlyCharges <= 85.35\ngini = 0.121\nsamples = 31\nvalue = [2, 29]'),
#  Text(0.4354107648725212, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4376770538243626, 0.6833333333333333, 'TotalCharges <= 169.15\ngini = 0.064\nsamples = 30\nvalue = [1, 29]'),
#  Text(0.43654390934844195, 0.65, 'TotalCharges <= 168.35\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4354107648725212, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4376770538243626, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4388101983002833, 0.65, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.44447592067988667, 0.7166666666666667, 'TotalCharges <= 423.275\ngini = 0.426\nsamples = 26\nvalue = [8, 18]'),
#  Text(0.443342776203966, 0.6833333333333333, 'MonthlyCharges <= 90.225\ngini = 0.488\nsamples = 19\nvalue = [8, 11]'),
#  Text(0.44107648725212467, 0.65, 'SeniorCitizen <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.43994334277620395, 0.6166666666666667, 'TotalCharges <= 253.45\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.4388101983002833, 0.5833333333333334, 'TotalCharges <= 215.2\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.4376770538243626, 0.55, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.43994334277620395, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.44107648725212467, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.44220963172804534, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.44560906515580734, 0.65, 'TotalCharges <= 231.775\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.44447592067988667, 0.6166666666666667, 'Partner_encode <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.443342776203966, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.44560906515580734, 0.5833333333333334, 'TotalCharges <= 169.475\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.44447592067988667, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.44674220963172806, 0.55, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.44674220963172806, 0.6166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.44560906515580734, 0.6833333333333333, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4509915014164306, 0.75, 'TotalCharges <= 526.675\ngini = 0.459\nsamples = 84\nvalue = [30, 54]'),
#  Text(0.4498583569405099, 0.7166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4521246458923513, 0.7166666666666667, 'MonthlyCharges <= 95.7\ngini = 0.444\nsamples = 81\nvalue = [27, 54]'),
#  Text(0.4509915014164306, 0.6833333333333333, 'MonthlyCharges <= 85.625\ngini = 0.433\nsamples = 79\nvalue = [25, 54]'),
#  Text(0.4498583569405099, 0.65, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4521246458923513, 0.65, 'MonthlyCharges <= 86.025\ngini = 0.453\nsamples = 72\nvalue = [25, 47]'),
#  Text(0.4498583569405099, 0.6166666666666667, 'TotalCharges <= 1242.6\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.44872521246458924, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4509915014164306, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.45439093484419263, 0.6166666666666667, 'MonthlyCharges <= 95.3\ngini = 0.438\nsamples = 68\nvalue = [22, 46]'),
#  Text(0.45325779036827196, 0.5833333333333334, 'TotalCharges <= 1033.925\ngini = 0.455\nsamples = 63\nvalue = [22, 41]'),
#  Text(0.4490084985835694, 0.55, 'TotalCharges <= 958.9\ngini = 0.493\nsamples = 34\nvalue = [15, 19]'),
#  Text(0.4478753541076487, 0.5166666666666667, 'MonthlyCharges <= 87.55\ngini = 0.464\nsamples = 30\nvalue = [11, 19]'),
#  Text(0.44674220963172806, 0.48333333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4490084985835694, 0.48333333333333334, 'MonthlyCharges <= 89.25\ngini = 0.488\nsamples = 26\nvalue = [11, 15]'),
#  Text(0.4478753541076487, 0.45, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.45014164305949006, 0.45, 'MonthlyCharges <= 94.975\ngini = 0.434\nsamples = 22\nvalue = [7, 15]'),
#  Text(0.4490084985835694, 0.4166666666666667, 'Dependents_encode <= 0.5\ngini = 0.408\nsamples = 21\nvalue = [6, 15]'),
#  ...]

# %%
# export_text 를 통해 문자( text )로 트리를 시각화 합니다.
# 너무 길어 한눈에 보기가 어려울 경우, max_depth 를 설정하면 특정 깊이까지만 보입니다.
from sklearn.tree import export_text
# 여기에 구현해 주세요.
print(export_text(model, max_depth=3))
# Out:
# |--- feature_1 <= 16.50
# |   |--- feature_2 <= 69.53
# |   |   |--- feature_1 <= 2.50
# |   |   |   |--- feature_2 <= 20.85
# |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |--- feature_2 >  20.85
# |   |   |   |   |--- truncated branch of depth 22
# |   |   |--- feature_1 >  2.50
# |   |   |   |--- feature_2 <= 20.93
# |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |--- feature_2 >  20.93
# |   |   |   |   |--- truncated branch of depth 16
# |   |--- feature_2 >  69.53
# |   |   |--- feature_3 <= 118.10
# |   |   |   |--- feature_3 <= 75.68
# |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |--- feature_3 >  75.68
# |   |   |   |   |--- truncated branch of depth 7
# |   |   |--- feature_3 >  118.10
# |   |   |   |--- feature_2 <= 85.17
# |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |--- feature_2 >  85.17
# |   |   |   |   |--- truncated branch of depth 20
# |--- feature_1 >  16.50
# |   |--- feature_2 <= 69.97
# |   |   |--- feature_2 <= 28.55
# |   |   |   |--- feature_1 <= 25.50
# |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |--- feature_1 >  25.50
# |   |   |   |   |--- truncated branch of depth 8
# |   |   |--- feature_2 >  28.55
# |   |   |   |--- feature_3 <= 1256.52
# |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |--- feature_3 >  1256.52
# |   |   |   |   |--- truncated branch of depth 17
# |   |--- feature_2 >  69.97
# |   |   |--- feature_1 <= 41.50
# |   |   |   |--- feature_8 <= 0.50
# |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |--- feature_8 >  0.50
# |   |   |   |   |--- truncated branch of depth 26
# |   |   |--- feature_1 >  41.50
# |   |   |   |--- feature_1 <= 69.50
# |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |--- feature_1 >  69.50
# |   |   |   |   |--- truncated branch of depth 14

# %% [markdown]
# ### 3-2) 피처 중요도 시각화 하기
#
# * 해당 이미지는 예시로 모델의 학습 결과에 따라 다르게 나올 수 있습니다.
#
# <img src="https://i.imgur.com/EtcMpCy.png" width="500">

# %%
# feature_importances_ 를 통해 모델의 피처 중요도를 추출합니다.

model.feature_importances_
# Out:
# array([0.01993144, 0.22743534, 0.35948894, 0.28152989, 0.02921721,
#        0.02462633, 0.02250885, 0.00559817, 0.02966384])

# %%
# 피처 중요도를 시각화 합니다.
# 여기에 구현해 주세요. 위 예시 이미지를 참고합니다.
sns.barplot(x=model.feature_importances_, y=feature_names)
# Out:
# <Axes: >

# %% [markdown]
# ### 3-3) 정확도(Accuracy)구하기
# - 모델이 얼마나 잘 예측했는지 측정해 봅니다.
# - 시험을 보고 나서 몇 개 맞았는지 틀렸는지 채점해 보는 과정과 유사하다고 보면 됩니다.
# - 실전 문제에서는 답이 없어서 우리가 예측을 해야겠지만 이 실습은 정답이 있는 모의고사 입니다.
# - 모의고사를 보면 내 실력이 어느정도 되는지 예측해 보는 것처럼 점수를 측정해 봅니다.

# %%
# 빈칸을 채워 정확도(accuracy) 를 구해주세요.
# 정답과 같이 예측한 값은 True 로 나오게 됩니다.
# True == 1 이기 때문에 평균값을 내면 정답을 맞춘 비율을 구할 수 있습니다.

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict)
# Out:
# 0.7199052132701422
